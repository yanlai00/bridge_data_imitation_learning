# %%
from semiparametrictransfer.data_sets.data_loader import FixLenVideoDataset
from semiparametrictransfer.utils.general_utils import AttrDict
import os
from semiparametrictransfer.models.gcbc_images import get_tlen_from_padmask

hp = AttrDict(data_dir=os.environ['DATA'] + '/spt_trainingdata/spt_control_experiments/control/widowx/sim/pick_only_gatorade/')

batch_size = 10
loader = FixLenVideoDataset(hp, phase='train').get_data_loader(batch_size)

for i_batch, sample_batched in enumerate(loader):
    actions = sample_batched['actions']
#     print(actions.shape)
#     print(sample_batched['pad_mask'].shape)
#     print(sample_batched['images'].shape)
    
    tlen = get_tlen_from_padmask(sample_batched['pad_mask'])
    print('tlen', tlen[0])
    print(actions[0, :tlen[0]-1, -1])
# Out:
# overriding param data_dir to value /mount/harddrive/trainingdata/spt_trainingdata/spt_control_experiments/control/widowx/sim/pick_only_gatorade/
# init dataloader for phase train with 459 files
# len train dataset 459
# tlen 28
# tensor([ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000, -0.7000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.7000])
# tlen 23
# tensor([ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#         -0.7000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.7000])
# tlen 30
# tensor([ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000, -0.7000,  0.0000,
# ...

# %%
import torch
import sys

print(sys.executable)
# Out:
# /home/febert/software/anaconda3/bin/python
